# %% [markdown]
# # Electrostatica Project DEF D
#
# Flavor text
#
# Dit project bestaat uit de volgende onderdelen:
# 1) Een puntlading in de oorsprong
# 2) Een uniform geladen schijf bestaande uit puntladingen
# 3) Een geladen schijf op een constant potentiaal
# 4) Twee geleidende platen op potentiaal V1 and -V1
# 5) Defferig
# 6) Verschillen tussen de theoretische wereld en de praktijk verklaren
#
# Instructies:
# - Git clone dit notebook, hiervoor staat een manual op brightspace
# - Beantwoord de vragen die in dit notbook voor komen.
#
# In deze opdracht zullen jullie verschillende problemen bestuderen die assymetrie hebben. De opdarchten sullen daardoor, cylindrische coordinaten (r,$\phi$,z) gebruiken, waarbij r dee afstand tot de z as is, z de hoogte en $\phi$ de hoek met de x-as. Alle gebruikte problemen zullen ook in de $\phi$ richting symetrisch zijn en die coordinaat zal dus niet uitmaken.
#
# Voor elke opdracht zal eerst het potentiaal bepaald worden en daarna zal het elektrische veld bepaald worden met de "finite difference" methode.

# %% [markdown]
# Vul de informatie in deze cel in:
#
# | Groep: XX     |  |
# | :-------------|:-------------|
# | Student naam 1| Student Studienummer 1 |
# | Student naam 2| Student Studienummer 2 |

# %%
import numpy as np
import matplotlib.pyplot as plt
from functions_electrostatics import *
#from IPython import display
from IPython.display import Image, display


epsilon0 = 8.854e-12  # Permittivity of free space (F/m)

"""============================================================================================
We first define the size of the domain of calculation and spatial discretization of the domain
"""

# grid of computation domain, the field is calculated in the (r,z) plane (axisymmetry):
width_domain = 5 # (m)
height_domain = width_domain # max distance from disk surface, above and below (m)
grid_step = 0.1 # grid step size (m)

# %% [markdown]
# ### 1) Een puntlading in de oorsprong

# %%
charge_one_point = 1e-14 # charge of one single point (C)
r, z, B = initialize_plane_grid_for_pt_charge_at_origin(height_domain,width_domain,grid_step)    
V = calculate_V_point_charge_at_origin(charge_one_point,r,z)
Er, Ez, normE = compute_E_pt_charge(V,B,grid_step) # using centered finite-difference method
#with Er the r component Ez the z component and normE the norm of the electricfield 
r_for_E = r[1:-1] # centered finite-difference method cannot calculate E at very first and very last grid point in r dimension
z_for_E = z[1:-1] # centered finite-difference method cannot calculate E at very first and very last grid point in z dimension
plot_results_pt_charge_at_origin(Ez,Er,normE,V,r,z,grid_step)

# %% [markdown]
# Q1.1)
# - Laat zien dat het electrische potentiaal afneemt met $\frac{1}{r}$.
# - Laat zien dat het electrische veld afneemt met $\frac{1}{r^2}$.

# %%
#Hint bepaal het potentiaal langs de z as.
#Hint 2 fit a loglog data transformtion

###
###Hier jouw code###
###

# %% [markdown]
# ### 2) Een uniform geladen schijf bestaande uit puntladingen
#
# Een uniform geladen schijf wordt hier gemaakt via het superpositie principe door een rooster te creeren van punten in de ruimte. Dan worden alle punten die binnen de schijf op z = 0 $m$ zitten een onderdeel van de schijf gemaakt.
#
# De z-as is de as van de schijf.
# De straal ($R$) van de schijf kan hieronder bepaald worden

# %%
disk_radius = 3 # (m)

# %%
r, z, B = initialize_plane_grid_for_uniformly_charged_disk(height_domain,width_domain,grid_step)
idx_z_zero = np.where(abs(z) < 1e-10)[0]
z_coord_DISK = 0 # (m) position of the disk on the z-axis
inter_charge_distance = grid_step # (m) distance between point charges
V, number_point_charges_on_disk = calculate_V_disk_at_origin_uniform_surface_charge_density(z_coord_DISK,charge_one_point,disk_radius,inter_charge_distance,r,z)
Er, Ez, normE = compute_E_disk(V,B,grid_step) # using centered finite-difference method
r_for_E = r[1:-1] # centered finite-difference method cannot calculate E at very first and very last grid point in r dimension
z_for_E = z[1:-1] # centered finite-difference method cannot calculate E at very first and very last grid point in z dimension
plot_results_disk(Ez,Er,normE,V,r,z,grid_step,disk_radius,z_coord_DISK,z_coord_DISK)

# %% [markdown]
# Q.2.1)
#
# Het aantal punten dat gebruikt wordt om de schijf te creeren is number_point_charges_on_disk,
# the charge of one single point charge is charge_one_point.
# - Bereken en print de ladingsdichtheid met een correcte eenheid.

# %%
###
###Hier jouw code###
###

# %% [markdown]
# Q.2.2)
#
# Hier is $\sigma$ de ladingsdichtheid.
# - Plot het electrische potentiaal langs de R as (z = 0 $m$).
# - Plot het potentiaal op de rand van de schijf in hetzelfde figuur $V = \sigma R/(\pi \epsilon_0)$
# (bekijk probleem 2.51 in het Griffiths' boek)
# - Plot het potentiaal in het centrum van de schijf in hetzelfde figuur $V = \sigma R/(2 \epsilon_0)$
# - Beschrijf en verklaar de mogelijke verschillen.

# %%
###
###Hier jouw code###
###

# %% [markdown]
# Q.2.3)
# - Plot het electrische potentiaal op de z-as(r=0).
#
# Het theoretische potentiaal op de as van een hele grote schijf is (R$>>$z):
# $V(z,r=0)=\frac{\sigma}{2\epsilon_0}\big( R - |z|\big)$
# zie probleeem 2.26 in het Griffiths boek.
#
# - Plot het theoretische component van het potentiaal op de as van een schijf met ladingsdichtheid $\sigma$.
# - Plot het z-component van het electrische veld op de as van de schijf (r=0).
# - Plot het theoretische electrische veld voor een oneindig geladen oppervlak $|E| = \sigma/(2 \epsilon_0)$ (zie Example 2.5 in het Griffith boek)
# - Waar benaderdt het electrische veld van een uniform geladen schijf dat van een oneindig geladen plaat?
# - Beschrijf en verklaar de verschillen die je opvallen.

# %%
###
###Hier jouw code###
###

# %% [markdown]
# Q.2.4)
#
# Het electrische veld een afstand z boven het midden van een uniform geladen schijf met een straal R en oppervlakte lading $\sigma$ wordt gegeven door:
# $$ \mathbf{E} = \frac{\sigma}{2\epsilon_0} \bigg[ 1- \frac{z}{\sqrt{R^2 + z^2}}\bigg] \hat{\mathbf{z}}$$
# Zie problem 2.6 in het boek van Griffith.
#
# - Voeg hieronder het figuur toe dat in de vorige vraag voor twee verschillende waardes van R. Dit kan met de command display(Image("folder-name/image-name")). Wat gebeurt er met de met het z-component van electrische veld als R toeneemt?
# - Wat moet de hoogte z zijn boven de schijf zodat het electrische veld door de schijf 10% van dat van een oneindig geladen plaat.

# %%
###
###Jouw code hier###
###

# %% [markdown]
# ### 3) Een geladen schijf op een constant potentiaal
#
# We zullen nu het verschil bestuderen tussen een uniform geladen schijf en een geleidende schijf sie op een bepaald potentiaal gehouden wordt.
#
# Hieronder wordt een numerieke oplossing voor de Laplace vergelijking bepaald met de gegeven randvoorwaarde.

# %%
V0 = 0 # electric potential at boundary of domain (V)

# one disk
z_pos_disk1 = 0 # z-coordinate of first conducting disk (m)
z_pos_disk2 = z_pos_disk1 # z-coordinate of second conducting disk (m)
V1 = 10 # electric potential of first conducting disk (V)
r, z, r_repmat, V, B, idx_R, idx_z1, idx_z2 = initialize_variables_Laplace(width_domain,disk_radius,height_domain,grid_step,z_pos_disk1,z_pos_disk2,V0,V1,V1)

"""--------------------------------------------------------------------
Field calculation for conducting disk
"""
solve_Laplace_equation(V,B,r_repmat,grid_step,idx_z1,idx_z2,idx_R,V1,V1,1e-3)
Er, Ez, normE = compute_E_disk(V,B,grid_step)
r_for_E = r[1:-1] # centered finite-difference method cannot calculate E at very first and very last grid point in r dimension
z_for_E = z[1:-1] # centered finite-difference method cannot calculate E at very first and very last grid point in z dimension

""""---------------------------------------------------------
Display calculated field
"""
plot_results_disk(Ez,Er,normE,V,r,z,grid_step,disk_radius,z_pos_disk1,z_pos_disk2)

# %% [markdown]
# Q.3.1)
# - Plot de electrische veld sterkte op de as van de schijf.
# - Wat is de norm van het electrische veld op de as heel dicht bij het midden van de schijf?
# - Hoe kan je de oppervlaktelading benaderen in het midden van de schijf?
# - How can you estimate the surface charge density at the surface of the disk at its center (r=0, z=0)?

# %%
###
###Jouw code hier###
###

# %% [markdown]
# Q.3.2)
# De oppervlakte lading $\sigma(r)$ van een geleidende schijf met straal $R$ is niet uniform op het opervlak van de schijf (Problems 2.58 and 2.63 Griffiths 5th edition):
# $$\sigma(r) = \frac{Q}{2 \pi R \sqrt{R^2 - r^2}}$$
#
# - Schat de totale lading Q op het oppervlak van de geleidende schijf met het resultaat van Q3.1
# - Vergelijk de oppervlakte lading in het centrum van de geleidende schijf met dat van een uniform geladen schijf met dezelfde totale lading.
# - Plot de oppervlakte lading van de geleidende schijf en op een uniform geladen schijf met dezelfde lading Q als een functie van de radius tussen 0 en R.

# %%
###
###Jouw code hier###
###

# %% [markdown]
# Q.3.3)
#
# - Waar is het maximum van het electrische veld?
# - Hoeveel hoger is dit maximum dan het veld bij het midden van de schijf?
# - Wat is de oorzaak van dit lokaal hoge veld?

# %%
###
###Jouw code hier###
###

# %% [markdown]
# ### 4) Twee geleidende platen op potentiaal V1 and -V1

# %%
# for two disks
spacing_between_disks = 2 # (m)
z_pos_disk1 = spacing_between_disks/2 # z-coordinate of first conducting disk (m)
z_pos_disk2 = -spacing_between_disks/2 # z-coordinate of second conducting disk (m)
V1 = 10 # electric potential of first conducting disk (V)
V2 = -10 # electric potential of second conducting disk (V)
r, z, r_repmat, V, B, idx_R, idx_z1, idx_z2 = initialize_variables_Laplace(width_domain,disk_radius,height_domain,grid_step,z_pos_disk1,z_pos_disk2,V0,V1,V2)

"""--------------------------------------------------------------------
Field calculation for the two conducting disks
"""
solve_Laplace_equation(V,B,r_repmat,grid_step,idx_z1,idx_z2,idx_R,V1,V2,1e-3)
Er, Ez, normE = compute_E_disk(V,B,grid_step)
r_for_E = r[1:-1] # centered finite-difference method cannot calculate E at very first and very last grid point in r dimension
z_for_E = z[1:-1] # centered finite-difference method cannot calculate E at very first and very last grid point in z dimension

""""---------------------------------------------------------
Display calculated field
"""
plot_results_disk(Ez,Er,normE,V,r,z,grid_step,disk_radius,z_pos_disk1,z_pos_disk2)

# %% [markdown]
# Q.4.1)
#
# - Gegeven het potentiaal tussen twee platen, wat is het theoretische electrische veld tussen de schijven?
# - Plot het z-component van het electrische veld op de as van de schijven.
# - Beschrijf het berekende electrische veld op de as tussen de twee schijven, komt dit overeen met het theoretische veld?
# - Vergelijk het berekende electrische veld tussen de twee schijven ($r=0$ and $z=0$) met dat van een enkele geleidende schijf op hetzelfde potentiaal(vraag Q3.1), welk voordeel heeft deze configuratie?

# %%
###
###your code here###
###

# %% [markdown]
# Q.4.2)
#
# - Wat is de verwachte oppervlakte lading op de binnenzijde van de twee schijven?
# - Wat is de verwachte totale lading op beide schijven?
# - Wat is de verwachte capaciteit van deze twee schijven?

# %%
###
###your code here###
###

# %% [markdown]
# Q.4.3)
#
# - Is de oppervlaktelading aan de buitenkant van de de schijven gelijk aan nul, beargumenteer waarom wel of niet.
# - Welke waarde heeft het z-component van het electrische veld op de as in de buurt van de buitenkant en binnenkant van beide schijven?
# - Wat kan je uit de vorige vraag concluderen over de oppervlaktelading op de binnenkant en buitenkant van de schijf?
# - Wat kan je hieruit concluderen uit de daadwerkelijke totale lading berekend in vraag 4.2?
# - Wat is de invloed hierop voor de capaciteit berekend in vraag 4.2?
# - Run de numerieke oplosser voor de laplace vergelijking opnieuw met een kleinere afstand tussen de schijven, wat verandert er?
#
# De daadwerkelijke totale lading voor verschillende ratios van afstanden s tot de atraal van de plaat wordt in de onderstaande afbeelding gegeven.
# - Bereken de daadwerkelijke totale lading met de resultaten van vraag 4.3.
# - Komt dit overeen met de precieze totale lading, leg uit waarom?

# %%
display(Image("figures/charge_circular_plates_edge_effects.png"))

# %%
###
###your code here###
###

# %% [markdown]
# ### 5) Voorbereidende opdracht voor de DEF ontwerpopdracht
#
# In deze vraag zullen we in gaan op benodigde voorkennis voor de ontwerpopdracht "Maak een sensor met condensatoren". Het is niet verplicht om deze opdracht gedaan te hebben voor de ontwerpopdracht maar het wordt wel sterk aangeraden.
#
# In deze vraag zullen we kijken naar de ideale vlakke plaat condensator. Als de afstand tussen de platen veel kleiner is dan de afstand groote van de platen dan wordt de aanname gemaakt dat het veld tussen de platen constant is en gelijk aan [formule] is en dat daarbuiten het veld 0 is. Deze aanname zal niet helemaal overeenkomen met de werkelijkheid, zoals je in deze opdracht en de fysieke DEF ontwerpopdracht achter zal komen.

# %% [markdown]
# Q.5.1)
#
# - Vind de formule voor de capaciteit van een vlakkeplaat condensator en een cylindercondensator, onder de aanname dat de afstand veel kleiner is dan de afmetingen van de condensator?
# - Schrijf een python functie die de relevante parameters als input neemt en de capaciteit als outnput heeft.

# %%
###
###your code here###
###

# %% [markdown]
# Q.5.2)
# - Bereken en plot de capciteit van een vlakkeplaat condensator van 10 bij 10 cm waarbij de afstand tussen de platen lineair toeneemt van 0.5mm tot 5mm.
# - Bereken en plot de capaciteit van een cylinder condensator met een binnendiameter van 9 mm en een buitendiameter van 10 mm en 10 cm lang, waarbij de binnencylineder er langzaam in 10 seconde uitgetrokken wordt.

# %%
###
###your code here###
###

# %% [markdown]
# ### 6) Reflectie opdracht voor na de fysieke ontwerpopdracht
#
# Deze opdracht bouwt voor op de physieke ontwerp opdracht, maak deze opdracht dus ook pas na de fysieke ontwerpopdracht.
#
# Als het goed is zullen jullie een andere opstelling gehad hebben voor de fysieke ontwerpopdracht dan elkaar. Kies voor deze opdraxcht een van jullie ontwerpen.
#
# Jullie gaan in deze opdracht het verschil tussen jullie voorspelde verband en jullie uiteindelijke verkregen kalibratie grafiek proberen te verklaren. Er zijn hier twee veelvoorkomende voorbeelden van verklaringen voor het verschil tussen jullie voorspellingen(deel a en b) en jullie data werk een van deze twee voorbeelden uit voor jullie data. Op het einde zijn nog een aantal vragen die voor beide delen beantwoord moeten worden.

# %% [markdown]
# #### 6a) Dunne laag niet meegerekende dielectricum.

# %% [markdown]
# Q.5.7)
#
# - Maak een nieuwe schets van je opstelling waarbij je de dikte van het extra dielectricum meeneemt.
# - Leid de analytische oplossing af van de capaciteit van de hierboven getekende situatie.
# - Programmeer de analytische oplossing in python.
# - Maak hierna een plot van het klaibratiegrafiek, oude en nieuwe analytische oplossing in een grafiek.
# - Beschrijf en verklaar de verschillen in tussen de grafieken.

# %%
display(Image("figures/capacitor_with_insulating_layers.png"))

# %% [markdown]
# Answer model for Q5.7:
#
# The inner and outer conductors could be coated with a thin insulator (plastic slab, coating or paint with thickness $t$) so that the water does not conduct current. The water should not directly contact either conductor. However, the presence of a thick insulator (thick compared to the air gap) would affect the calculation of the capacitance (see Problems 4.18 and 4.19 in Griffiths 5th edition).
#
# Let's now calculate the modified relationship between capacitance and water height.
#
# Applying the same method as in Q5.3, we find: $E_{\text{in plastic}} = \frac{\sigma_{free}^{capacitor~plate}}{\epsilon_{\text{plastic}}}$
#
# The electric potential difference is: $V^{(+)} - V^{(-)} = -\int_{(-)}^{(+)}\mathbf{E}\cdot d\mathbf{l} = E_{\text{in plastic}} ~t + E_{\text{in water/air}} ~s + E_{\text{in plastic}} ~t$
#
# Thus $V^{(+)} - V^{(-)} = 2t \frac{\sigma_{free}^{capacitor~plate}}{\epsilon_{\text{plastic}}} + s \frac{\sigma_{free}^{capacitor~plate}}{\epsilon_{\text{water/air}}} = \frac{\sigma_{free}^{capacitor~plate}}{\epsilon_0} \bigg( \frac{2t}{\epsilon_r^{plastic}} + \frac{s}{\epsilon_r^{water/air}} \bigg)$
#
# The total charge in the capacitor is $Q = Q_{water} + Q_{air} = W \epsilon_0 \Delta V \bigg( \frac{h}{ \frac{2t}{\epsilon_r^{plastic}} + \frac{s}{\epsilon_r^{water}} } + \frac{L-h}{ \frac{2t}{\epsilon_r^{plastic}} + \frac{s}{\epsilon_r^{air}} } \bigg)$
#
# The capacitance is thus: $C = \frac{Q}{\Delta V} = W \epsilon_0 \bigg( \frac{h}{ \frac{2t}{\epsilon_r^{plastic}} + \frac{s}{\epsilon_r^{water}} } + \frac{L-h}{ \frac{2t}{\epsilon_r^{plastic}} + \frac{s}{\epsilon_r^{air}} } \bigg)$
#
# For PVC slab, acrylic insulating paint or epoxy coating, $\epsilon_r^{plastic} \approx 3.5$.
#
# The capacitance is decreased by the insulator, therefore you can increase the number of parallel plates to have a capacitance of at least 0.5nF for a water height of 1mm.

# %%
"""================================
Answer model for Q5.7
"""

# with Eps_r_air = 1
Eps_r_water = 80
h = np.linspace(1, 150, num=20)/1000 # (m) water height

s = 0.001 # (m) spacing between flat plates
w = 0.15 # (m) width of capacitor flat plate
# two flat square plates without thin insulator:
C0 = w/s*epsilon0*((Eps_r_water-1)*h+l)
# two flat square plates with 0.5mm thin insulator:
Eps_r_plastic = 3.5
t = 0.0002 # (m) thickness of insulator
C = w*epsilon0*(h/(2*t/Eps_r_plastic + s/Eps_r_water) + (l-h)/(2*t/Eps_r_plastic + s))

plt.figure(figsize=(9,4)) # Width, height in inches.
plt.plot(h*1000 , C0*1e9, ':ro' )
plt.plot(h*1000 , C*1e9, ':kx' )
plt.legend(['without plastic insulator','with %1.1f-mm thick plastic insulator' %(t*1000)])
plt.xlabel('Water heigth [mm]')
plt.ylabel('Electric capacitance [nF]')
plt.title('Two flat square plates (150 mm x 150 mm), spacing = %1.1f' %(s*1000) + ' mm')
plt.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 12
#      10 w = 0.15 # (m) width of capacitor flat plate
#      11 # two flat square plates without thin insulator:
# ---> 12 C0 = w/s*epsilon0*((Eps_r_water-1)*h+l)
#      13 # two flat square plates with 0.5mm thin insulator:
#      14 Eps_r_plastic = 3.5
#
# NameError: name 'l' is not defined

# %%
# Remark:
# The effect of capillary action is significant for a spacing of 1-10 mm.
# But a calibration should enable an accurate measurement of water height.

gamma = 0.072 # (N/m)
rho = 1000 # (kg/m^3)
s = 0.001 # (m)
g = 9.81 # (m/s^2)
#contact_angle_deg = 30 # for clean metal-water
contact_angle_deg = 75 # for clean PVC-water
h = 2*gamma*np.cos(contact_angle_deg*np.pi/180)/ (rho* g * s) # (m)
print('For a spacing of %1.2f ' %(s*1000) +' mm, the water height increase by capillary action for parallel plate capacitor = %1.2f' %(h*1000) +' mm')

# %% [markdown]
# Q.6a.1)
#
# Edge effect

# %%
dr = r_for_E[1]-r_for_E[0]
dz = z_for_E[1]-z_for_E[0]
epsilon0 = 8.85e-12

print(len(r_for_E),len(z_for_E))
print(r_for_E[30])


E_vlak_z0= np.sum(Er[62,:30]*r_for_E[:30])* dr
E_vlak_zmax = np.sum(Er[58,:30]*r_for_E[:30])*dr
E_vlak_rmax = np.sum(Ez[58:62,30])*dz*r_for_E[30]

Egauss =2*np.pi*( E_vlak_z0+E_vlak_zmax+E_vlak_rmax)

Q = Egauss*epsilon0

print(Q)
C = Q/abs(V1-V2)
print(C)
# Out:
# 48 98
# 3.1
# 6.304078273556851e-10
# 3.1520391367784253e-11

# %% [markdown]
# Bereken de capaciteit met het electrisch veld berekent in vraag 4
# - Bereken de totale lading
# - Berken de capaciteit
# - Verklaar verschillen tussen je ontwerp grafiek en het grafiek in deze vraag gemaakt
