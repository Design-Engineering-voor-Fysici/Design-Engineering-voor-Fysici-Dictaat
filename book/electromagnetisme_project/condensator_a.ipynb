# %% [markdown]
# ## Condensator opdracht 1a

# %% [markdown]
# ## Opdrachten

# %% [markdown]
# Deel 1: Condensatoren achtergrond.
#
# Tekening maken van cylinder condensator en vlakke plaat.
#
# Formule geven voor getekende capciteit(bedoeld als verzin zelf welke parameters relevant zijn).
#
# Pyhton functie maken om capciteit te berekenen van beide.
#
# Een aantal configuraties die zij moeten doorrekenen

# %% [markdown]
# 1. Maak een tekening van een vlakke plaat en een cylinder condensator. Geef alle relevante parameters aan in de tekening.

# %% [markdown]
# Plaats hier de tekening met uitleg van de parameters.

# %% [markdown]
# 2.  Leid voor beide condensatoren een formule voor de capaciteit af aan de hand van de parameters in jullie tekening. Neem hierbij ook de diëlektrische constante constante mee.

# %% [markdown]
# Vervang deze tekst door jullie afleiding.

# %% [markdown]
# 3. Schrijf een python functie die de relevante parameters voor beide condensatoren als input neemt en de capaciteit als output heeft.

# %%
##Schrijf hier jullie functie

# %% [markdown]
# 4. Gebruik jouw code om de capaciteit te berekenen van een cylinder condensator die met een binnen straal van 1 cm en een buitendiameter van 1.2 cm. Deze cylinder is gevuld met water en is 10 cm hoog.

# %% [markdown]
# 5. Gebruik jouw code om de capaciteit te berekenen van een vlakke plaat condensator met platen van 20 bij 20 cm deze condensator is gevuld met lucht. De afstand tussen de platen is 1 mm.

# %% [markdown]
# 6. Plot de capaciteit van de condensator uit opdracht 5 als de afstand tussen de platen toeneemt van 1 mm naar 10 mm

# %% [markdown]
# Deel 2:
# In dit deel gaan we verder in op het ontwerpen van een sensor die gebruikt maak van een varierende capaciteit . Hiervoor zullen we een mini ontwerpcylus doorlopen, hier beginnen we met de synthese.
#
# Dit gaan we eerst doen door een regen meter, die de totaal gevallen neerslag op een dag meet. Dit varieert van dag tot dag maar is nog nooit boven de 150 mm gekomen. Lage capaciteiten kunnen soms moeilijk te meten zijn, daarom moet jullie capaciteit altijd hoger dan 1 nF zijn. Let op dit is een ontwerpopdracht waar jullie de vrijheid krijgen om echt jullie eigen ontwerp te maken, gebruik dit ook.

# %% [markdown]
# 7. Geef 3 SMART criteria waaraan de sensor moet voldoen.

# %% [markdown]
# Schrijf hier jullie criteria

# %% [markdown]
# 8. Maak een schets van jullie sensor.

# %% [markdown]
# Voeg je antwoord toe aan deze cel.

# %% [markdown]
# Deel 3:
# Hieronder gaan we kijken naar de fysica van onze sensor.

# %% [markdown]
# 9. Leid een analytisch verband af tussen de hoeveelheid neerslag en de capaciteit van jullie regen meter.

# %% [markdown]
# Voeg je antwoord toe aan deze cel

# %% [markdown]
# 10. Schrijf code om de capaciteit te berekenen als functie van de hoeveelheid gevallen regen en plot dit voor een regenval van 1 tot 150 mm.

# %%
#Schrijf hier jouw code

# %% [markdown]
# Deel 3:
# Hier gaan we verder in op het productie process.

# %% [markdown]
# 11. In een productie process gaat er altijd iets fout. Een veelvoorkomend probleem is dat onderdelen net andere afmetingen hebben dan dat jij dacht. Controleer hoe goed bestand tegen dit probleem jullie ontwerp is door bij twee belangrijke parameters kleine vatriaties te plotten.

# %%
##Schrijf hier jouw code

# %% [markdown]
# Dit is het einde van deel a van de condensator opdracht hierna kunnen jullie verder
