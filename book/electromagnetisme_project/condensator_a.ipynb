# %% [markdown]
# ## Condensator opdracht 1a
#
# Jullie zullen in dit deel een regen meter ontwerpen die te totaal gevallen regen op een dag meet, met een condensator.

# %% [markdown]
# ## Achtergrond informatie
#
# De hoogst gemeten regenval in nederland was lager dan 150 mm in een dag.
#
# ## Criteria
#
# 1. De regen meter moet een bereik hebben van 1mm tot 150mm.
# 2. Om met een multimeter de capaciteit goed te kunnen meten moet de capaciteit altijd hoger dan 1 nF.
# 3. De sensor moet in een kubus van 150mm breed passen
#
# Let op dit zijn de minimale criteria voel je vrij om extra criteria toe te voegen.

# %% [markdown]
# ## Opdrachten

# %% [markdown]
# 1. Wat zijn de dielectrische constantes van water en lucht?

# %%
## Geef antwoord in deze cel.

# %% [markdown]
# 2. Kies een simpele geometrie, zoals vlakke platen of holle cylinders. Schets de manier waarmee jullie het regenwater gaan opvangen, zorg ervoor dat in je ontwerp de hoogte van het water stijgt en zo de capaciteit verandert als er meer water bijkomt. Beschrijf kwalitatief waarom de stijging van het water de capaciteit verandert

# %% [markdown]
# Vervang deze tekst voor een geschreven antwoord en de schets van jullie sensor.

# %% [markdown]
# 3. Vind een analytische uitdrukking voor de relatie tussen de capaciteit en de regenval (water hoogte). Leg je stappen om tot de uitdrukkingen te komen uit.

# %% [markdown]
# Vervang deze tekst met je antwoord op vraag 3

# %% [markdown]
# 4. Hoe kan je de nauwkeurigheid van de sensor maximaliseren? (nauwkeurigheid in farad per mm).
#    Hint bereken de afgeleide van de capaciteit naar een relevante grootheid.

# %% [markdown]
# Vul hier jullie afleiding en uitleg aan.

# %% [markdown]
# 5. Welke fysische en praktische grenzen beperken de maximum nauwkeurigheid van jullie sensor?

# %% [markdown]
# Vervang deze cel met jullie uitleg.

# %% [markdown]
# 6. Bepaal afmetingen voor je sensor, denk hierbij afstand tussen de platen, dikte van de platen en de afmetingen van de platen. Kies ook materialen voor de onderdelen van je sensor. Leg je keuzes uit En teken je ontwerp met de juiste afmetingen.

# %% [markdown]
# Voeg je antwoord toe aan deze cel.

# %% [markdown]
# 7. Schrijf python code die de capaciteit berekent van je sensor. bij een gegeven parameters

# %%
#Schrijf hier jouw code

# %% [markdown]
# 8. Plot het verband tussen de capaciteit en da hoogte van het water bij jullie gekozen ontwerp. Neem hierbij de hoogte tussen de 1 en 150 mm. Controleer dat de capaciteit altijd hoger is dan 1 nF, als dit niet het geval is update je antwoord op vragen 2 tot en met 8 en leg uit hoe jullie je ontwerp hebben aangepast zodat het aan de eisen voldoet.

# %%
##Schrijf hier jouw code

# %% [markdown]
# 9. Jullie zullen een batterij gebruiken om een constant voltage over de condensator te behouden. Geef in jullie tekening aan hoe jullie de batterij aansluiten en leg uit waarom jullie dat op die manier doen.

# %% [markdown]
# Voeg hier jullie afbeelding toe en leg uit

# %% [markdown]
# 10. Geef in jullie tekening aan waar de ladingen zich bevinden op jullie condensator als deze onder constant voltage gehouden wordt. Leg ook uit waar in de sensor de meeste vrije ladingen liggen.
