# %% [markdown]
# ## Condensator opdracht 1b

# %% [markdown]
# Deze opdracht is een vervolg van condensator opdracht 1a en gaat over waarom de gebouwde sensor af zal wijken van wat er analytisch berekened is. Deze opdracht is bedoeld om te maken na de physieke condensator ontwerpopdracht in week 3.

# %% [markdown]
# 1. Electrische geleidbaarheid van regen water is vrij klein, maar niet 0. Hoe kunnen jullie het ontwerp verbeteren, zodat er geen stroom gaat lopen tussen de condensatorplaten. Leg je oplossing uit en voeg deze aan de tekening toe.

# %% [markdown]
# Voeg hier jullie geupdate tekening en uitleg toe.

# %% [markdown]
# 2. De physieke sensor uit jullie ontwerp zal een andere relatie hebben tussen de capaciteit en de hoogte. Leg uit wat de oorzaken hiervan kunnen zijn en hoe je alsnog een accurate meting kan krijgen?

# %% [markdown]
# Antwoord vraag 2

# %% [markdown]
# 3. Leg uit hoe een simpele multimeter de capaciteit zou kunnen meten (leg de meet methode uit).

# %% [markdown]
# Antwoord vraag 3
